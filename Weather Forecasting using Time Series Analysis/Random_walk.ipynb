# %%
# Importing Libraries
from timeit import timeit
from itertools import accumulate
from numpy import cumsum
from random import gauss
from random import seed
from pandas import Series
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
from pandas.plotting import autocorrelation_plot
matplotlib.style.use('ggplot')

# %%
seed(333)

# %%
newArr = np.random.normal(0,3.0,100)

# series = sum(newArr)
series = Series(newArr)
print(series.describe())
# Out:
# count    100.000000
# mean      -0.016934
# std        2.782334
# min       -6.602277
# 25%       -2.034435
# 50%       -0.284239
# 75%        2.199356
# max        6.005948
# dtype: float64

# %%
# Plotting Random Walk
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Random Walk', fontsize=24, fontweight='bold')
series.plot()
plt.xlabel('Time')
plt.ylabel('White_Noise')
# Out:
# Text(0,0.5,'White_Noise')

# %%
autocorrelation_plot(series)

# %%
from statsmodels.tsa.arima_model import ARIMA
from pandas import datetime

# %%
#from ggplot import *

# %%
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = "11, 8"

# %%
from statsmodels.tsa.stattools import acf

# %%
import random

# %%
random.seed(333)

# %%
mu=0

# %%
sigma = 3.0

# %%
white_noise  = np.random.normal(mu, sigma, 100)

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Random Walk', fontsize=24, fontweight='bold')
plt.plot(white_noise)
plt.xlabel('Time')
plt.ylabel('White_Noise')
# Out:
# Text(0,0.5,'White_Noise')

# %%
 #plt.plot(acf(white_noise))

# %%
autocorrelation_plot(white_noise)

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Series Random Walk', fontsize=24, fontweight='bold')
plot_acf(white_noise, lags=20)
plt.xlabel('Lag')
plt.ylabel('ACF')
# Out:
# Text(0,0.5,'ACF')
