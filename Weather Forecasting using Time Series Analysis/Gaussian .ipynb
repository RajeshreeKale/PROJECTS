# %%
from random import gauss
from random import seed
from pandas import Series
from pandas.tools.plotting import autocorrelation_plot
# seed random number generator
seed(333)
# create white noise series
series = [gauss(0.0, 3.0) for i in range(100)]
series = Series(series)
print(series.describe())
# Out:
# count    100.000000
# mean       0.145967
# std        3.386071
# min       -7.850151
# 25%       -2.600413
# 50%        0.173352
# 75%        2.216813
# max        9.529484
# dtype: float64

# %%
from random import gauss
from random import seed
from pandas import Series
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
from pandas.plotting import autocorrelation_plot
matplotlib.style.use('ggplot')

# %%
seed(3333)

# %%
series = [gauss(0.0, 3.0) for i in range(100)]
series = Series(series)
print(series.describe())
# Out:
# count    100.000000
# mean      -0.145006
# std        3.377877
# min       -8.338342
# 25%       -2.628852
# 50%        0.218172
# 75%        2.301524
# max        7.966523
# dtype: float64

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Gaussian White Noise ACF function', fontsize=24, fontweight='bold')
ax = fig.add_subplot(111)
plt.xlabel('Time')
plt.ylabel('White_noise')
series.plot()
#pyplot.show()

# %%
autocorrelation_plot(series)
#pyplot.show()

# %%
pd.plotting.autocorrelation_plot(series);

# %%
#np.var(series, dtype=np.float64)
np.var(series)
# Out:
# 11.29595522507078

# %%
from statsmodels.tsa.arima_model import ARIMA
from pandas import datetime

# %%
#from ggplot import *

# %%
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = "11, 8"

# %%
from statsmodels.tsa.stattools import acf

# %%
import random

# %%
random.seed(3333)

# %%
mu=0

# %%
sigma = 3.0

# %%
white_noise  = np.random.normal(mu, sigma, 100)

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Guassian White Noise ACF Function', fontsize=24, fontweight='bold')
plt.plot(white_noise)
plt.xlabel('Time')
plt.ylabel('White_Noise')

# %%
import statistics

# %%
statistics.variance(white_noise)
# Out:
# 10.809858535826947

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
# Plotting ACF 
plot_acf(white_noise, lags=20)
