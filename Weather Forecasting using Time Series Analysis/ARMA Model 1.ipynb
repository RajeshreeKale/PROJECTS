# %%
seed(555)
# x <- arima.sim(n=1000, model=list(ar=0.5, ma=-0.5))
# plot(x)

# %%
import statsmodels.api as sm

# %%
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.tsa.api as smt
import matplotlib.pyplot as plt

# %%
#model= ARIMA(series(p= ,d=(0.84,0.62),q=)

# %%
from pandas import Series
newArr = np.random.normal(0,3.0,100)
series = Series(newArr)
print(series.describe())
# Out:
# count    100.000000
# mean      -0.338868
# std        3.204398
# min       -9.521357
# 25%       -2.180293
# 50%       -0.187191
# 75%        1.756832
# max        5.956598
# dtype: float64

# %%
#model= ARIMA(series,order=(0,0,[0.84,0.62]))

# %%
#model = tsa.ARIMA(series)
#result = model.fit(order(2,1), trend='c')

# %%
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
from pandas import DataFrame
import datetime as dt
from pandas import Series

# %%
def parser(x):
            return dt.datetime.strptime(x, "%Y-%m-%d %H:%M:%S")

# %%
#(0.84)

# %%
# arimaM = ARIMA(series, order=(5,1,0))
# arimaM = ARIMA(series, order=(1,0,2))
arimaM = ARIMA(series, order=(5,1,4))
arimaMfit = arimaM.fit( disp=0)
print(arimaMfit.summary())
# plot residual errors
errors = DataFrame(arimaMfit.resid)
errors.plot()
pyplot.show()
errors.plot(kind='kde')

pyplot.show()

#print(errors.describe())

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Series Ma', fontsize=24, fontweight='bold')
plot_acf(series, lags=30)
plt.xlabel('Lag')
plt.ylabel('ACF')
# Out:
# Text(0,0.5,'ACF')

# %%
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
from pandas import DataFrame
import datetime as dt
from pandas import Series
from random import seed
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_pacf
#series = Series.from_csv('daily-minimum-temperatures.csv', header=0)

# %%
#seed(1)
#x = arima.sim(n=1000, model=list(ar=0.5, ma=-0.5))
#pyplot(x)

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Series Random Walk', fontsize=24, fontweight='bold')
plot_pacf(series, lags=30)
plt.xlabel('Lag')
plt.ylabel('PCF')
#yplot_show()
# Out:
# Text(0,0.5,'PCF')

# %%
# import statsmodels.api as sm

# my_order = (1, 1, 1)
# my_seasonal_order = (1, 1, 1, 12)
# # define model
# model = SARIMAX(data, order=my_order, seasonal_order=my_seasonal_order)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 16

# %%
import warnings
import itertools
warnings.filterwarnings("ignore") # specify to ignore warning messages

# %%
import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint, adfuller
from pandas import Series
from random import seed

# %%
def TestStationaryPlot(ts):
    rol_mean = ts.rolling(window = 12, center = False).mean()
    rol_std = ts.rolling(window = 12, center = False).std(1.2)
    moving_avg = series.rolling(12).mean()
    series_moving_avg_diff = mte - moving_avg
plt.plot(series)
plt.plot(moving_avg, color='red')
# plt.xticks(fontsize = 25)
# plt.yticks(fontsize = 25)
# plt.xlabel('Time (years)', fontsize = 25)
# plt.ylabel('CO2 Emission (MMT)', fontsize = 25)
# plt.title('CO2 emission from electric power generation', fontsize = 25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-99eee7b7d9fc> in <module>()
#       5     series_moving_avg_diff = mte - moving_avg
#       6 plt.plot(series)
# ----> 7 plt.plot(moving_avg, color='red')
#       8 # plt.xticks(fontsize = 25)
#       9 # plt.yticks(fontsize = 25)
#
# NameError: name 'moving_avg' is not defined

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Series Ma', fontsize=24, fontweight='bold')
plot_acf(series, lags=30)
plt.xlabel('Lag')
plt.ylabel('ACF')
# Out:
# Text(0,0.5,'ACF')

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Series Random Walk', fontsize=24, fontweight='bold')
plot_pacf(series, lags=30)
plt.xlabel('Lag')
plt.ylabel('PCF')
#yplot_show()
# Out:
# Text(0,0.5,'PCF')
